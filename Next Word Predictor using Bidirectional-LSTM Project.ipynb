# %%
with open('faqs.txt', 'r', encoding='utf-8') as file:
    faqs = file.read()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
tokenizer.word_index
# Out:
# {'a': 1,
#  'the': 2,
#  'to': 3,
#  'is': 4,
#  'of': 5,
#  'in': 6,
#  'int': 7,
#  'and': 8,
#  'c': 9,
#  'i': 10,
#  'function': 11,
#  'can': 12,
#  'be': 13,
#  'for': 14,
#  'program': 15,
#  'are': 16,
#  'this': 17,
#  '3': 18,
#  'we': 19,
#  'if': 20,
#  '0': 21,
#  'an': 22,
#  'loop': 23,
#  'value': 24,
#  'file': 25,
#  'as': 26,
#  'b': 27,
#  'float': 28,
#  'array': 29,
#  '1': 30,
#  'code': 31,
#  'using': 32,
#  '→': 33,
#  'or': 34,
#  'used': 35,
#  'it': 36,
#  'ptr': 37,
#  'write': 38,
#  'memory': 39,
#  'n': 40,
#  'by': 41,
#  'pointer': 42,
#  '2': 43,
#  'instructions': 44,
#  'like': 45,
#  'd': 46,
#  'x': 47,
#  'string': 48,
#  'from': 49,
#  'not': 50,
#  'printf': 51,
#  'variable': 52,
#  '5': 53,
#  'with': 54,
#  'which': 55,
#  'char': 56,
#  'that': 57,
#  'use': 58,
#  'will': 59,
#  'type': 60,
#  '4': 61,
#  'operator': 62,
#  'call': 63,
#  'integer': 64,
#  'else': 65,
#  'while': 66,
#  'on': 67,
#  'operators': 68,
#  '8': 69,
#  'variables': 70,
#  'example': 71,
#  'character': 72,
#  'types': 73,
#  'return': 74,
#  'condition': 75,
#  'user': 76,
#  'case': 77,
#  'main': 78,
#  'functions': 79,
#  'quick': 80,
#  'quiz': 81,
#  'number': 82,
#  'structures': 83,
#  'structure': 84,
#  'j': 85,
#  'data': 86,
#  'true': 87,
#  'address': 88,
#  'our': 89,
#  'at': 90,
#  'have': 91,
#  'first': 92,
#  'there': 93,
#  'print': 94,
#  'values': 95,
#  '–': 96,
#  'harry': 97,
#  'all': 98,
#  'note': 99,
#  '10': 100,
#  'control': 101,
#  'y': 102,
#  'statement': 103,
#  'now': 104,
#  'strings': 105,
#  'language': 106,
#  'follows': 107,
#  'input': 108,
#  'struct': 109,
#  'defined': 110,
#  'employee': 111,
#  'factorial': 112,
#  'other': 113,
#  'executed': 114,
#  'any': 115,
#  'syntax': 116,
#  'when': 117,
#  'false': 118,
#  'given': 119,
#  'passed': 120,
#  'sum': 121,
#  'recursion': 122,
#  'one': 123,
#  'some': 124,
#  'programs': 125,
#  'these': 126,
#  'statements': 127,
#  'numbers': 128,
#  'declare': 129,
#  'z': 130,
#  'store': 131,
#  'st': 132,
#  'important': 133,
#  'compiler': 134,
#  '7': 135,
#  'create': 136,
#  'void': 137,
#  'order': 138,
#  'two': 139,
#  'you': 140,
#  '30': 141,
#  'below': 142,
#  'read': 143,
#  'marks': 144,
#  'pointers': 145,
#  'programming': 146,
#  'just': 147,
#  'way': 148,
#  'what': 149,
#  'into': 150,
#  'called': 151,
#  '‘': 152,
#  'line': 153,
#  'so': 154,
#  'scanf': 155,
#  'set': 156,
#  'k': 157,
#  'but': 158,
#  'sometimes': 159,
#  'output': 160,
#  'stored': 161,
#  'very': 162,
#  'must': 163,
#  'similar': 164,
#  'no': 165,
#  'change': 166,
#  'switch': 167,
#  'h': 168,
#  'add': 169,
#  'library': 170,
#  'characters': 171,
#  'declaration': 172,
#  'returns': 173,
#  'above': 174,
#  'following': 175,
#  'expression': 176,
#  'whether': 177,
#  '100': 178,
#  'another': 179,
#  'loops': 180,
#  'name': 181,
#  'prototype': 182,
#  'arguments': 183,
#  '87994': 184,
#  'arr': 185,
#  'null': 186,
#  'content': 187,
#  'allocation': 188,
#  'malloc': 189,
#  'computer': 190,
#  'us': 191,
#  'each': 192,
#  'written': 193,
#  'etc': 194,
#  "'a'": 195,
#  '9': 196,
#  'real': 197,
#  'single': 198,
#  'break': 199,
#  'do': 200,
#  'include': 201,
#  'starts': 202,
#  'arithmetic': 203,
#  'multiple': 204,
#  'here': 205,
#  'more': 206,
#  'becomes': 207,
#  'check': 208,
#  's': 209,
#  'also': 210,
#  'make': 211,
#  'c1': 212,
#  'c2': 213,
#  'programmer': 214,
#  'initialized': 215,
#  'once': 216,
#  '‘i’': 217,
#  'gets': 218,
#  '22': 219,
#  'reading': 220,
#  'elements': 221,
#  'complex': 222,
#  'free': 223,
#  'calloc': 224,
#  'constants': 225,
#  'constant': 226,
#  'assigned': 227,
#  'allowed': 228,
#  'does': 229,
#  'three': 230,
#  '’': 231,
#  'stdio': 232,
#  'inside': 233,
#  'same': 234,
#  'comments': 235,
#  'comment': 236,
#  'multi': 237,
#  'between': 238,
#  'f': 239,
#  'take': 240,
#  'should': 241,
#  'contains': 242,
#  'look': 243,
#  'initialize': 244,
#  'valid': 245,
#  'cannot': 246,
#  'floats': 247,
#  'priority': 248,
#  'evaluated': 249,
#  'practice': 250,
#  'conditions': 251,
#  'least': 252,
#  'writing': 253,
#  'calculate': 254,
#  'entered': 255,
#  'natural': 256,
#  'then': 257,
#  'consider': 258,
#  'size': 259,
#  'display': 260,
#  'good': 261,
#  'prints': 262,
#  'its': 263,
#  'arrays': 264,
#  'created': 265,
#  'e1': 266,
#  'files': 267,
#  'open': 268,
#  'num': 269,
#  'fgetc': 270,
#  'dynamic': 271,
#  'realloc': 272,
#  'where': 273,
#  'level': 274,
#  'source': 275,
#  'execute': 276,
#  'binary': 277,
#  'rules': 278,
#  'than': 279,
#  'primarily': 280,
#  'typedef': 281,
#  'continue': 282,
#  'sizeof': 283,
#  'am': 284,
#  'executes': 285,
#  'present': 286,
#  'execution': 287,
#  'notes': 288,
#  'particular': 289,
#  'point': 290,
#  'operations': 291,
#  'commonly': 292,
#  'multiplication': 293,
#  'operands': 294,
#  'why': 295,
#  'since': 296,
#  '33': 297,
#  'precedence': 298,
#  'associativity': 299,
#  'table': 300,
#  'chapter': 301,
#  'looks': 302,
#  'block': 303,
#  'logical': 304,
#  'cases': 305,
#  '90': 306,
#  'even': 307,
#  'done': 308,
#  '11': 309,
#  '0l': 310,
#  'printing': 311,
#  'counter': 312,
#  'decrement': 313,
#  'next': 314,
#  'iteration': 315,
#  'definition': 316,
#  'during': 317,
#  'declared': 318,
#  'calling': 319,
#  'recursive': 320,
#  'base': 321,
#  '87998': 322,
#  'swap': 323,
#  'bytes': 324,
#  'access': 325,
#  'contiguous': 326,
#  'target': 327,
#  'opening': 328,
#  'txt': 329,
#  'fptr': 330,
#  'allocated': 331,
#  'systems': 332,
#  'run': 333,
#  'e': 334,
#  'install': 335,
#  'machine': 336,
#  'keywords': 337,
#  'stores': 338,
#  'names': 339,
#  'whose': 340,
#  '‘a’': 341,
#  'known': 342,
#  'available': 343,
#  'default': 344,
#  'basic': 345,
#  'instruction': 346,
#  'terminated': 347,
#  'semicolon': 348,
#  'every': 349,
#  'they': 350,
#  'about': 351,
#  'plain': 352,
#  'after': 353,
#  'ignored': 354,
#  'text': 355,
#  'sequence': 356,
#  'checks': 357,
#  'has': 358,
#  '‘b’': 359,
#  'invalid': 360,
#  'before': 361,
#  'equal': 362,
#  'perform': 363,
#  'subtraction': 364,
#  'both': 365,
#  'demoted': 366,
#  'because': 367,
#  'four': 368,
#  'conditional': 369,
#  'want': 370,
#  'might': 371,
#  'it’s': 372,
#  'relational': 373,
#  'logic': 374,
#  'usage': 375,
#  'increases': 376,
#  'find': 377,
#  'student': 378,
#  '50': 379,
#  'pass': 380,
#  'assume': 381,
#  'income': 382,
#  'tax': 383,
#  '20': 384,
#  'year': 385,
#  'again': 386,
#  'do–while': 387,
#  'infinite': 388,
#  'increment': 389,
#  '‘n’': 390,
#  'test': 391,
#  'keep': 392,
#  'body': 393,
#  'most': 394,
#  'implement': 395,
#  'them': 396,
#  'keyword': 397,
#  '“good': 398,
#  'passing': 399,
#  'parameters': 400,
#  'itself': 401,
#  '…': 402,
#  'further': 403,
#  'defining': 404,
#  'ch': 405,
#  'demonstrate': 406,
#  'u': 407,
#  'temp': 408,
#  '12': 409,
#  'index': 410,
#  'printarray': 411,
#  'initializing': 412,
#  'automatically': 413,
#  'puts': 414,
#  'strcpy': 415,
#  's1': 416,
#  'space': 417,
#  'strcmp': 418,
#  'facebook': 419,
#  'arrow': 420,
#  'complexno': 421,
#  'fopen': 422,
#  'fclose': 423,
#  'fputc': 424,
#  'eof': 425,
#  'allocate': 426,
#  'communicate': 427,
#  'languages': 428,
#  'uses': 429,
#  'need': 430,
#  'area': 431,
#  'vs': 432,
#  'mingw': 433,
#  'compilation': 434,
#  "computer's": 435,
#  'directly': 436,
#  'storing': 437,
#  'dal': 438,
#  'meaningful': 439,
#  'readability': 440,
#  'entity': 441,
#  'changed': 442,
#  'within': 443,
#  'quotes': 444,
#  '32': 445,
#  'double': 446,
#  'long': 447,
#  'short': 448,
#  'volatile': 449,
#  'hello': 450,
#  'something': 451,
#  'slashes': 452,
#  'information': 453,
#  'converts': 454,
#  'easily': 455,
#  'performs': 456,
#  'certain': 457,
#  'screen': 458,
#  'integers': 459,
#  'floating': 460,
#  '“address': 461,
#  'of”': 462,
#  'means': 463,
#  'copied': 464,
#  'how': 465,
#  'variations': 466,
#  "'i'": 467,
#  'mathematical': 468,
#  'addition': 469,
#  'division': 470,
#  'later': 471,
#  'crucial': 472,
#  'part': 473,
#  'able': 474,
#  '8y': 475,
#  'simple': 476,
#  '1st': 477,
#  '2nd': 478,
#  '3rd': 479,
#  'parenthesis': 480,
#  'taken': 481,
#  'always': 482,
#  'decision': 483,
#  'step': 484,
#  'being': 485,
#  'met': 486,
#  'checked': 487,
#  'optional': 488,
#  'assignment': 489,
#  'non': 490,
#  '“1': 491,
#  '0”': 492,
#  'evaluates': 493,
#  'reduces': 494,
#  'such': 495,
#  'instead': 496,
#  'along': 497,
#  'thus': 498,
#  'ladder': 499,
#  'typical': 500,
#  'last': 501,
#  'only': 502,
#  'ternary': 503,
#  'choice': 504,
#  'c3': 505,
#  'based': 506,
#  '80': 507,
#  '70': 508,
#  '60': 509,
#  'determine': 510,
#  '40': 511,
#  'over': 512,
#  'easy': 513,
#  'tell': 514,
#  'keeps': 515,
#  'executing': 516,
#  'initial': 517,
#  'exist': 518,
#  '‘do': 519,
#  'while’': 520,
#  'terms': 521,
#  '‘for’': 522,
#  'until': 523,
#  '‘break’': 524,
#  'let': 525,
#  '‘continue’': 526,
#  'skip': 527,
#  'skips': 528,
#  'possible': 529,
#  'track': 530,
#  'doing': 531,
#  'time': 532,
#  'points': 533,
#  'talk': 534,
#  'required': 535,
#  'get': 536,
#  'takes': 537,
#  '77': 538,
#  'happens': 539,
#  'copy': 540,
#  'direct': 541,
#  'algorithms': 542,
#  'terminates': 543,
#  'without': 544,
#  'obtain': 545,
#  'working': 546,
#  'programmers': 547,
#  '‘j’': 548,
#  'pointing': 549,
#  '‘k’': 550,
#  'calls': 551,
#  'sending': 552,
#  'reference': 553,
#  'modify': 554,
#  'collection': 555,
#  'accessing': 556,
#  'creating': 557,
#  'dimension': 558,
#  'dimensions': 559,
#  'blocks': 560,
#  '0’': 561,
#  'locations': 562,
#  "'r'": 563,
#  'adds': 564,
#  'enough': 565,
#  'word': 566,
#  'needed': 567,
#  'reinitialized': 568,
#  'standard': 569,
#  'strlen': 570,
#  'under': 571,
#  'second': 572,
#  'strcat': 573,
#  's2': 574,
#  'negative': 575,
#  "string's": 576,
#  'mismatching': 577,
#  'positive': 578,
#  'far': 579,
#  'joke': 580,
#  'new': 581,
#  'salary': 582,
#  '71': 583,
#  'properties': 584,
#  'show': 585,
#  '‘typedef’': 586,
#  'alias': 587,
#  'img': 588,
#  'o': 589,
#  'mode': 590,
#  'modes': 591,
#  'r': 592,
#  'w': 593,
#  'exists': 594,
#  'fscanf': 595,
#  "'c'": 596,
#  'end': 597,
#  'been': 598,
#  'runtime': 599,
#  'dma': 600,
#  'stands': 601,
#  'medium': 602,
#  'computers': 603,
#  '‘hindi’': 604,
#  '‘english’': 605,
#  'deliver': 606,
#  'oldest': 607,
#  'finest': 608,
#  'was': 609,
#  'developed': 610,
#  'dennis': 611,
#  'ritchie': 612,
#  't’s': 613,
#  'bell': 614,
#  'labs': 615,
#  'usa': 616,
#  '1972': 617,
#  'wide': 618,
#  'variety': 619,
#  'major': 620,
#  'parts': 621,
#  'windows': 622,
#  'linux': 623,
#  'operating': 624,
#  'driver': 625,
#  'devices': 626,
#  'tablets': 627,
#  'printers': 628,
#  'embedded': 629,
#  'faster': 630,
#  'limited': 631,
#  'microwave': 632,
#  'cameras': 633,
#  'develop': 634,
#  'games': 635,
#  'latency': 636,
#  'react': 637,
#  'quickly': 638,
#  'installation': 639,
#  'editor': 640,
#  'gcc': 641,
#  'compile': 642,
#  'process': 643,
#  'translating': 644,
#  'high': 645,
#  'low': 646,
#  'cpu': 647,
#  'consists': 648,
#  'specific': 649,
#  'architecture': 650,
#  'their': 651,
#  'respective': 652,
#  'websites': 653,
#  'game': 654,
#  'container': 655,
#  '‘value’': 656,
#  'kitchen': 657,
#  'containers': 658,
#  'rice': 659,
#  'sugar': 660,
#  'naming': 661,
#  'alphabet': 662,
#  'underscore': 663,
#  'commas': 664,
#  'blanks': 665,
#  'special': 666,
#  'symbol': 667,
#  'sensitive': 668,
#  'enhances': 669,
#  '6': 670,
#  '322': 671,
#  'enclosed': 672,
#  'reserved': 673,
#  'words': 674,
#  'meaning': 675,
#  'already': 676,
#  'auto': 677,
#  'enum': 678,
#  'register': 679,
#  'extern': 680,
#  'union': 681,
#  'const': 682,
#  'unsigned': 683,
#  'signed': 684,
#  'goto': 685,
#  'static': 686,
#  'learning': 687,
#  'follow': 688,
#  'applicable': 689,
#  'program’s': 690,
#  'case–sensitive': 691,
#  'clarify': 692,
#  'start': 693,
#  'forward': 694,
#  'lying': 695,
#  'would': 696,
#  'ends': 697,
#  'understood': 698,
#  'combination': 699,
#  'finally': 700,
#  'executable': 701,
#  'lot': 702,
#  'valuable': 703,
#  'carry': 704,
#  'out': 705,
#  'tasks': 706,
#  'instance': 707,
#  'receiving': 708,
#  'assign': 709,
#  'supplied': 710,
#  'indicated': 711,
#  'recipe': 712,
#  'prepare': 713,
#  'dish': 714,
#  "'b'": 715,
#  "'j'": 716,
#  'j1': 717,
#  'previously': 718,
#  'assigning': 719,
#  'modulus': 720,
#  'legal': 721,
#  'illegal': 722,
#  'modular': 723,
#  'remainder': 724,
#  'applied': 725,
#  'sign': 726,
#  'numerator': 727,
#  'assumed': 728,
#  'pe': 729,
#  'ab': 730,
#  'exponentiation': 731,
#  'however': 732,
#  'pow': 733,
#  'math': 734,
#  'conversion': 735,
#  'operation': 736,
#  'compatibility': 737,
#  'losing': 738,
#  'fractional': 739,
#  'conversely': 740,
#  'promoted': 741,
#  'matching': 742,
#  'retaining': 743,
#  'precision': 744,
#  'promotion': 745,
#  'ans': 746,
#  '333': 747,
#  '3x': 748,
#  'bodmas': 749,
#  'longer': 750,
#  'apply': 751,
#  'answer': 752,
#  'questions': 753,
#  'provided': 754,
#  'lists': 755,
#  'higher': 756,
#  'absence': 757,
#  'tie': 758,
#  'care': 759,
#  'left': 760,
#  'right': 761,
#  'pro': 762,
#  'tip': 763,
#  'confusion': 764,
#  'determines': 765,
#  'flow': 766,
#  'v': 767,
#  'dt': 768,
#  '‘21': 769,
#  'dec': 770,
#  '2020’': 771,
#  'divisible': 772,
#  '97': 773,
#  'explain': 774,
#  'evaluation': 775,
#  'watch': 776,
#  'comedy': 777,
#  'videos': 778,
#  'youtube': 779,
#  'day': 780,
#  'sunday': 781,
#  'junk': 782,
#  'food': 783,
#  'friend’s': 784,
#  'birthday': 785,
#  'hostel': 786,
#  'buy': 787,
#  'umbrella': 788,
#  'raining': 789,
#  'money': 790,
#  'meal': 791,
#  'your': 792,
#  'favourite': 793,
#  'bhindi': 794,
#  'listed': 795,
#  'menu': 796,
#  'decisions': 797,
#  'depends': 798,
#  'too': 799,
#  'making': 800,
#  'if–else': 801,
#  '23': 802,
#  '18': 803,
#  'drive': 804,
#  'necessary': 805,
#  'evaluate': 806,
#  'examples': 807,
#  'whereas': 808,
#  'equality': 809,
#  'zero': 810,
#  'considered': 811,
#  '“and”': 812,
#  '“or”': 813,
#  '“not”': 814,
#  'provide': 815,
#  '“0': 816,
#  '1”': 817,
#  'indentation': 818,
#  'come': 819,
#  'rescue': 820,
#  'clause': 821,
#  'forming': 822,
#  'indents': 823,
#  '“else”': 824,
#  '“else': 825,
#  'if”': 826,
#  'fail': 827,
#  '4th': 828,
#  '5th': 829,
#  '6th': 830,
#  '7th': 831,
#  '8th': 832,
#  'shorthand': 833,
#  '“if': 834,
#  'else”': 835,
#  'alternatives': 836,
#  'matched': 837,
#  'against': 838,
#  'c3…': 839,
#  'matches': 840,
#  'subsequent': 841,
#  '“case”': 842,
#  '“default”': 843,
#  'grade': 844,
#  'his': 845,
#  'necessarily': 846,
#  'ascending': 847,
#  'occur': 848,
#  'rarely': 849,
#  'failed': 850,
#  'requires': 851,
#  'total': 852,
#  'subject': 853,
#  'subjects': 854,
#  'paid': 855,
#  'government': 856,
#  'per': 857,
#  'slabs': 858,
#  'mentioned': 859,
#  'slab': 860,
#  '5l': 861,
#  'amount': 862,
#  'leap': 863,
#  'lowercase': 864,
#  'greatest': 865,
#  'few': 866,
#  'sets': 867,
#  'to100': 868,
#  'hence': 869,
#  'repeatedly': 870,
#  'never': 871,
#  'getting': 872,
#  'well': 873,
#  'increased': 874,
#  'decreased': 875,
#  'compound': 876,
#  'translates': 877,
#  'works': 878,
#  '‘while’': 879,
#  'simpler': 880,
#  'say': 881,
#  'setting': 882,
#  'checking': 883,
#  'updating': 884,
#  'decrementing': 885,
#  'running': 886,
#  'become': 887,
#  'runs': 888,
#  'steps': 889,
#  '“i”': 890,
#  'none': 891,
#  'tested': 892,
#  'decremented': 893,
#  'reverse': 894,
#  'exit': 895,
#  'irrespective': 896,
#  'whenever': 897,
#  '“break”': 898,
#  'encountered': 899,
#  'sent': 900,
#  'outside': 901,
#  'see': 902,
#  'help': 903,
#  '1000': 904,
#  'immediately': 905,
#  'move': 906,
#  'skipping': 907,
#  'everything': 908,
#  '“continue”': 909,
#  'rest': 910,
#  'indicate': 911,
#  'behaviour': 912,
#  'completely': 913,
#  'exits': 914,
#  'reversed': 915,
#  'twice': 916,
#  'ten': 917,
#  'occurring': 918,
#  'repeat': 919,
#  'prime': 920,
#  'bigger': 921,
#  "it's": 922,
#  'piece': 923,
#  'chunks': 924,
#  'reuse': 925,
#  'task': 926,
#  'reused': 927,
#  'times': 928,
#  'hi': 929,
#  'message': 930,
#  'informs': 931,
#  'indicates': 932,
#  'instructs': 933,
#  "function's": 934,
#  'made': 935,
#  'exact': 936,
#  'pauses': 937,
#  'temporarily': 938,
#  'suspends': 939,
#  'transfers': 940,
#  'finishes': 941,
#  'resumes': 942,
#  'morning': 943,
#  'morning”': 944,
#  'afternoon': 945,
#  'afternoon”': 946,
#  'night': 947,
#  'night”': 948,
#  '1→2→3': 949,
#  'indirectly': 950,
#  "let's": 951,
#  'grouped': 952,
#  'together': 953,
#  'disk': 954,
#  'avoid': 955,
#  'rewriting': 956,
#  'independently': 957,
#  'snippet': 958,
#  'specifies': 959,
#  'placeholders': 960,
#  'actual': 961,
#  'doesn’t': 962,
#  'misnomer': 963,
#  '‘change’': 964,
#  'pretends': 965,
#  'remains': 966,
#  'square': 967,
#  'side': 968,
#  '‘recursive’': 969,
#  'x3': 970,
#  'dry': 971,
#  'often': 972,
#  'algorithm': 973,
#  'particularly': 974,
#  'suited': 975,
#  'problems': 976,
#  'divided': 977,
#  'smaller': 978,
#  'subproblems': 979,
#  'computation': 980,
#  'tree': 981,
#  'traversal': 982,
#  'iterative': 983,
#  'approaches': 984,
#  'straightforward': 985,
#  'efficient': 986,
#  'stops': 987,
#  'correction': 988,
#  'clarifies': 989,
#  'prevents': 990,
#  'ensures': 991,
#  'correctly': 992,
#  'due': 993,
#  'oversight': 994,
#  'indefinitely': 995,
#  'reaching': 996,
#  'potentially': 997,
#  'causing': 998,
#  'stack': 999,
#  'overflow': 1000,
#  ...}

# %%
len(tokenizer.word_index)
# Out:
# 1163

# %%
input_sequences = []
for sentence in faqs.split('\n'):
    tokenize_sentence = tokenizer.texts_to_sequences([sentence])[0]

    for i in range(1,len(tokenize_sentence)):
        input_sequences.append(tokenize_sentence[:i+1])

# %%
input_sequences
# Out:
# [[190, 146],
#  [190, 146, 4],
#  [190, 146, 4, 1],
#  [190, 146, 4, 1, 602],
#  [190, 146, 4, 1, 602, 14],
#  [190, 146, 4, 1, 602, 14, 191],
#  [190, 146, 4, 1, 602, 14, 191, 3],
#  [190, 146, 4, 1, 602, 14, 191, 3, 427],
#  [190, 146, 4, 1, 602, 14, 191, 3, 427, 54],
#  [190, 146, 4, 1, 602, 14, 191, 3, 427, 54, 603],
#  [190, 146, 4, 1, 602, 14, 191, 3, 427, 54, 603, 147],
#  [190, 146, 4, 1, 602, 14, 191, 3, 427, 54, 603, 147, 45],
#  [190, 146, 4, 1, 602, 14, 191, 3, 427, 54, 603, 147, 45, 19],
#  [190, 146, 4, 1, 602, 14, 191, 3, 427, 54, 603, 147, 45, 19, 58],
#  [190, 146, 4, 1, 602, 14, 191, 3, 427, 54, 603, 147, 45, 19, 58, 604],
#  [190, 146, 4, 1, 602, 14, 191, 3, 427, 54, 603, 147, 45, 19, 58, 604, 34],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   606],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   606,
#   89],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   606,
#   89,
#   44],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   606,
#   89,
#   44,
#   3],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   606,
#   89,
#   44,
#   3,
#   2],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   606,
#   89,
#   44,
#   3,
#   2,
#   190],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   606,
#   89,
#   44,
#   3,
#   2,
#   190,
#   149],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   606,
#   89,
#   44,
#   3,
#   2,
#   190,
#   149,
#   4],
#  [190,
#   146,
#   4,
#   1,
#   602,
#   14,
#   191,
#   3,
#   427,
#   54,
#   603,
#   147,
#   45,
#   19,
#   58,
#   604,
#   34,
#   605,
#   3,
#   427,
#   54,
#   192,
#   113,
#   146,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   606,
#   89,
#   44,
#   3,
#   2,
#   190,
#   149,
#   4,
#   9],
#  [9, 4],
#  [9, 4, 1],
#  [9, 4, 1, 146],
#  [9, 4, 1, 146, 106],
#  [9, 4],
#  [9, 4, 123],
#  [9, 4, 123, 5],
#  [9, 4, 123, 5, 2],
#  [9, 4, 123, 5, 2, 607],
#  [9, 4, 123, 5, 2, 607, 8],
#  [9, 4, 123, 5, 2, 607, 8, 608],
#  [9, 4, 123, 5, 2, 607, 8, 608, 146],
#  [9, 4, 123, 5, 2, 607, 8, 608, 146, 428],
#  [9, 609],
#  [9, 609, 610],
#  [9, 609, 610, 41],
#  [9, 609, 610, 41, 611],
#  [9, 609, 610, 41, 611, 612],
#  [9, 609, 610, 41, 611, 612, 90],
#  [9, 609, 610, 41, 611, 612, 90, 90],
#  [9, 609, 610, 41, 611, 612, 90, 90, 613],
#  [9, 609, 610, 41, 611, 612, 90, 90, 613, 614],
#  [9, 609, 610, 41, 611, 612, 90, 90, 613, 614, 615],
#  [9, 609, 610, 41, 611, 612, 90, 90, 613, 614, 615, 616],
#  [9, 609, 610, 41, 611, 612, 90, 90, 613, 614, 615, 616, 6],
#  [9, 609, 610, 41, 611, 612, 90, 90, 613, 614, 615, 616, 6, 617],
#  [9, 609, 610, 41, 611, 612, 90, 90, 613, 614, 615, 616, 6, 617, 429],
#  [9, 609, 610, 41, 611, 612, 90, 90, 613, 614, 615, 616, 6, 617, 429, 5],
#  [9, 609, 610, 41, 611, 612, 90, 90, 613, 614, 615, 616, 6, 617, 429, 5, 9],
#  [9, 106],
#  [9, 106, 4],
#  [9, 106, 4, 35],
#  [9, 106, 4, 35, 3],
#  [9, 106, 4, 35, 3, 15],
#  [9, 106, 4, 35, 3, 15, 1],
#  [9, 106, 4, 35, 3, 15, 1, 618],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619, 5],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619, 5, 332],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619, 5, 332, 124],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619, 5, 332, 124, 5],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619, 5, 332, 124, 5, 2],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619, 5, 332, 124, 5, 2, 429],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619, 5, 332, 124, 5, 2, 429, 5],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619, 5, 332, 124, 5, 2, 429, 5, 9],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619, 5, 332, 124, 5, 2, 429, 5, 9, 16],
#  [9, 106, 4, 35, 3, 15, 1, 618, 619, 5, 332, 124, 5, 2, 429, 5, 9, 16, 26],
#  [9,
#   106,
#   4,
#   35,
#   3,
#   15,
#   1,
#   618,
#   619,
#   5,
#   332,
#   124,
#   5,
#   2,
#   429,
#   5,
#   9,
#   16,
#   26,
#   107],
#  [620, 621],
#  [620, 621, 5],
#  [620, 621, 5, 622],
#  [620, 621, 5, 622, 623],
#  [620, 621, 5, 622, 623, 8],
#  [620, 621, 5, 622, 623, 8, 113],
#  [620, 621, 5, 622, 623, 8, 113, 624],
#  [620, 621, 5, 622, 623, 8, 113, 624, 332],
#  [620, 621, 5, 622, 623, 8, 113, 624, 332, 16],
#  [620, 621, 5, 622, 623, 8, 113, 624, 332, 16, 193],
#  [620, 621, 5, 622, 623, 8, 113, 624, 332, 16, 193, 6],
#  [620, 621, 5, 622, 623, 8, 113, 624, 332, 16, 193, 6, 9],
#  [9, 4],
#  [9, 4, 35],
#  [9, 4, 35, 3],
#  [9, 4, 35, 3, 38],
#  [9, 4, 35, 3, 38, 625],
#  [9, 4, 35, 3, 38, 625, 125],
#  [9, 4, 35, 3, 38, 625, 125, 14],
#  [9, 4, 35, 3, 38, 625, 125, 14, 626],
#  [9, 4, 35, 3, 38, 625, 125, 14, 626, 45],
#  [9, 4, 35, 3, 38, 625, 125, 14, 626, 45, 627],
#  [9, 4, 35, 3, 38, 625, 125, 14, 626, 45, 627, 628],
#  [9, 4, 35, 3, 38, 625, 125, 14, 626, 45, 627, 628, 194],
#  [9, 106],
#  [9, 106, 4],
#  [9, 106, 4, 35],
#  [9, 106, 4, 35, 3],
#  [9, 106, 4, 35, 3, 15],
#  [9, 106, 4, 35, 3, 15, 629],
#  [9, 106, 4, 35, 3, 15, 629, 332],
#  [9, 106, 4, 35, 3, 15, 629, 332, 273],
#  [9, 106, 4, 35, 3, 15, 629, 332, 273, 125],
#  [9, 106, 4, 35, 3, 15, 629, 332, 273, 125, 430],
#  [9, 106, 4, 35, 3, 15, 629, 332, 273, 125, 430, 3],
#  [9, 106, 4, 35, 3, 15, 629, 332, 273, 125, 430, 3, 333],
#  [9, 106, 4, 35, 3, 15, 629, 332, 273, 125, 430, 3, 333, 630],
#  [9, 106, 4, 35, 3, 15, 629, 332, 273, 125, 430, 3, 333, 630, 6],
#  [9, 106, 4, 35, 3, 15, 629, 332, 273, 125, 430, 3, 333, 630, 6, 631],
#  [9, 106, 4, 35, 3, 15, 629, 332, 273, 125, 430, 3, 333, 630, 6, 631, 39],
#  [9, 106, 4, 35, 3, 15, 629, 332, 273, 125, 430, 3, 333, 630, 6, 631, 39, 632],
#  [9,
#   106,
#   4,
#   35,
#   3,
#   15,
#   629,
#   332,
#   273,
#   125,
#   430,
#   3,
#   333,
#   630,
#   6,
#   631,
#   39,
#   632,
#   633],
#  [9,
#   106,
#   4,
#   35,
#   3,
#   15,
#   629,
#   332,
#   273,
#   125,
#   430,
#   3,
#   333,
#   630,
#   6,
#   631,
#   39,
#   632,
#   633,
#   194],
#  [9, 4],
#  [9, 4, 35],
#  [9, 4, 35, 3],
#  [9, 4, 35, 3, 634],
#  [9, 4, 35, 3, 634, 635],
#  [9, 4, 35, 3, 634, 635, 22],
#  [9, 4, 35, 3, 634, 635, 22, 431],
#  [9, 4, 35, 3, 634, 635, 22, 431, 273],
#  [9, 4, 35, 3, 634, 635, 22, 431, 273, 636],
#  [9, 4, 35, 3, 634, 635, 22, 431, 273, 636, 4],
#  [9, 4, 35, 3, 634, 635, 22, 431, 273, 636, 4, 162],
#  [9, 4, 35, 3, 634, 635, 22, 431, 273, 636, 4, 162, 133],
#  [9, 4, 35, 3, 634, 635, 22, 431, 273, 636, 4, 162, 133, 10],
#  [9, 4, 35, 3, 634, 635, 22, 431, 273, 636, 4, 162, 133, 10, 334],
#  [9, 4, 35, 3, 634, 635, 22, 431, 273, 636, 4, 162, 133, 10, 334, 2],
#  [9, 4, 35, 3, 634, 635, 22, 431, 273, 636, 4, 162, 133, 10, 334, 2, 190],
#  [9, 4, 35, 3, 634, 635, 22, 431, 273, 636, 4, 162, 133, 10, 334, 2, 190, 163],
#  [9,
#   4,
#   35,
#   3,
#   634,
#   635,
#   22,
#   431,
#   273,
#   636,
#   4,
#   162,
#   133,
#   10,
#   334,
#   2,
#   190,
#   163,
#   637],
#  [9,
#   4,
#   35,
#   3,
#   634,
#   635,
#   22,
#   431,
#   273,
#   636,
#   4,
#   162,
#   133,
#   10,
#   334,
#   2,
#   190,
#   163,
#   637,
#   638],
#  [9,
#   4,
#   35,
#   3,
#   634,
#   635,
#   22,
#   431,
#   273,
#   636,
#   4,
#   162,
#   133,
#   10,
#   334,
#   2,
#   190,
#   163,
#   637,
#   638,
#   3],
#  [9,
#   4,
#   35,
#   3,
#   634,
#   635,
#   22,
#   431,
#   273,
#   636,
#   4,
#   162,
#   133,
#   10,
#   334,
#   2,
#   190,
#   163,
#   637,
#   638,
#   3,
#   76],
#  [9,
#   4,
#   35,
#   3,
#   634,
#   635,
#   22,
#   431,
#   273,
#   636,
#   4,
#   162,
#   133,
#   10,
#   334,
#   2,
#   190,
#   163,
#   637,
#   638,
#   3,
#   76,
#   108],
#  [9,
#   4,
#   35,
#   3,
#   634,
#   635,
#   22,
#   431,
#   273,
#   636,
#   4,
#   162,
#   133,
#   10,
#   334,
#   2,
#   190,
#   163,
#   637,
#   638,
#   3,
#   76,
#   108,
#   639],
#  [19, 59],
#  [19, 59, 58],
#  [19, 59, 58, 432],
#  [19, 59, 58, 432, 31],
#  [19, 59, 58, 432, 31, 26],
#  [19, 59, 58, 432, 31, 26, 89],
#  [19, 59, 58, 432, 31, 26, 89, 31],
#  [19, 59, 58, 432, 31, 26, 89, 31, 640],
#  [19, 59, 58, 432, 31, 26, 89, 31, 640, 3],
#  [19, 59, 58, 432, 31, 26, 89, 31, 640, 3, 38],
#  [19, 59, 58, 432, 31, 26, 89, 31, 640, 3, 38, 89],
#  [19, 59, 58, 432, 31, 26, 89, 31, 640, 3, 38, 89, 31],
#  [19, 59, 58, 432, 31, 26, 89, 31, 640, 3, 38, 89, 31, 8],
#  [19, 59, 58, 432, 31, 26, 89, 31, 640, 3, 38, 89, 31, 8, 335],
#  [19, 59, 58, 432, 31, 26, 89, 31, 640, 3, 38, 89, 31, 8, 335, 433],
#  [19, 59, 58, 432, 31, 26, 89, 31, 640, 3, 38, 89, 31, 8, 335, 433, 641],
#  [19, 59, 58, 432, 31, 26, 89, 31, 640, 3, 38, 89, 31, 8, 335, 433, 641, 134],
#  [19,
#   59,
#   58,
#   432,
#   31,
#   26,
#   89,
#   31,
#   640,
#   3,
#   38,
#   89,
#   31,
#   8,
#   335,
#   433,
#   641,
#   134,
#   3],
#  [19,
#   59,
#   58,
#   432,
#   31,
#   26,
#   89,
#   31,
#   640,
#   3,
#   38,
#   89,
#   31,
#   8,
#   335,
#   433,
#   641,
#   134,
#   3,
#   642],
#  [19,
#   59,
#   58,
#   432,
#   31,
#   26,
#   89,
#   31,
#   640,
#   3,
#   38,
#   89,
#   31,
#   8,
#   335,
#   433,
#   641,
#   134,
#   3,
#   642,
#   89],
#  [19,
#   59,
#   58,
#   432,
#   31,
#   26,
#   89,
#   31,
#   640,
#   3,
#   38,
#   89,
#   31,
#   8,
#   335,
#   433,
#   641,
#   134,
#   3,
#   642,
#   89,
#   9],
#  [19,
#   59,
#   58,
#   432,
#   31,
#   26,
#   89,
#   31,
#   640,
#   3,
#   38,
#   89,
#   31,
#   8,
#   335,
#   433,
#   641,
#   134,
#   3,
#   642,
#   89,
#   9,
#   15],
#  [434, 4],
#  [434, 4, 2],
#  [434, 4, 2, 643],
#  [434, 4, 2, 643, 5],
#  [434, 4, 2, 643, 5, 644],
#  [434, 4, 2, 643, 5, 644, 645],
#  [434, 4, 2, 643, 5, 644, 645, 274],
#  [434, 4, 2, 643, 5, 644, 645, 274, 275],
#  [434, 4, 2, 643, 5, 644, 645, 274, 275, 31],
#  [434, 4, 2, 643, 5, 644, 645, 274, 275, 31, 193],
#  [434, 4, 2, 643, 5, 644, 645, 274, 275, 31, 193, 6],
#  [434, 4, 2, 643, 5, 644, 645, 274, 275, 31, 193, 6, 146],
#  [434, 4, 2, 643, 5, 644, 645, 274, 275, 31, 193, 6, 146, 428],
#  [434, 4, 2, 643, 5, 644, 645, 274, 275, 31, 193, 6, 146, 428, 45],
#  [434, 4, 2, 643, 5, 644, 645, 274, 275, 31, 193, 6, 146, 428, 45, 9],
#  [434, 4, 2, 643, 5, 644, 645, 274, 275, 31, 193, 6, 146, 428, 45, 9, 150],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336,
#   31],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336,
#   31,
#   648],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336,
#   31,
#   648,
#   5],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336,
#   31,
#   648,
#   5,
#   277],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336,
#   31,
#   648,
#   5,
#   277,
#   44],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336,
#   31,
#   648,
#   5,
#   277,
#   44,
#   649],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336,
#   31,
#   648,
#   5,
#   277,
#   44,
#   649,
#   3],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336,
#   31,
#   648,
#   5,
#   277,
#   44,
#   649,
#   3,
#   1],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336,
#   31,
#   648,
#   5,
#   277,
#   44,
#   649,
#   3,
#   1,
#   435],
#  [434,
#   4,
#   2,
#   643,
#   5,
#   644,
#   645,
#   274,
#   275,
#   31,
#   193,
#   6,
#   146,
#   428,
#   45,
#   9,
#   150,
#   336,
#   31,
#   55,
#   4,
#   2,
#   646,
#   274,
#   31,
#   57,
#   1,
#   435,
#   647,
#   12,
#   276,
#   436,
#   336,
#   31,
#   648,
#   5,
#   277,
#   44,
#   649,
#   3,
#   1,
#   435,
#   650],
#  [19, 12],
#  [19, 12, 335],
#  [19, 12, 335, 432],
#  [19, 12, 335, 432, 31],
#  [19, 12, 335, 432, 31, 8],
#  [19, 12, 335, 432, 31, 8, 433],
#  [19, 12, 335, 432, 31, 8, 433, 49],
#  [19, 12, 335, 432, 31, 8, 433, 49, 651],
#  [19, 12, 335, 432, 31, 8, 433, 49, 651, 652],
#  [19, 12, 335, 432, 31, 8, 433, 49, 651, 652, 653],
#  [147, 335],
#  [147, 335, 36],
#  [147, 335, 36, 45],
#  [147, 335, 36, 45, 1],
#  [147, 335, 36, 45, 1, 654],
#  [70, 225],
#  [70, 225, 337],
#  [70, 225, 337, 70],
#  [1, 52],
#  [1, 52, 4],
#  [1, 52, 4, 1],
#  [1, 52, 4, 1, 655],
#  [1, 52, 4, 1, 655, 55],
#  [1, 52, 4, 1, 655, 55, 338],
#  [1, 52, 4, 1, 655, 55, 338, 1],
#  [1, 52, 4, 1, 655, 55, 338, 1, 656],
#  [1, 52, 4, 1, 655, 55, 338, 1, 656, 6],
#  [1, 52, 4, 1, 655, 55, 338, 1, 656, 6, 657],
#  [1, 52, 4, 1, 655, 55, 338, 1, 656, 6, 657, 19],
#  [1, 52, 4, 1, 655, 55, 338, 1, 656, 6, 657, 19, 91],
#  [1, 52, 4, 1, 655, 55, 338, 1, 656, 6, 657, 19, 91, 658],
#  [1, 52, 4, 1, 655, 55, 338, 1, 656, 6, 657, 19, 91, 658, 437],
#  [1, 52, 4, 1, 655, 55, 338, 1, 656, 6, 657, 19, 91, 658, 437, 659],
#  [1, 52, 4, 1, 655, 55, 338, 1, 656, 6, 657, 19, 91, 658, 437, 659, 438],
#  [1, 52, 4, 1, 655, 55, 338, 1, 656, 6, 657, 19, 91, 658, 437, 659, 438, 660],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164,
#   3],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164,
#   3,
#   57],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164,
#   3,
#   57,
#   70],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164,
#   3,
#   57,
#   70,
#   6],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164,
#   3,
#   57,
#   70,
#   6,
#   9],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164,
#   3,
#   57,
#   70,
#   6,
#   9,
#   338],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164,
#   3,
#   57,
#   70,
#   6,
#   9,
#   338,
#   24],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164,
#   3,
#   57,
#   70,
#   6,
#   9,
#   338,
#   24,
#   5],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164,
#   3,
#   57,
#   70,
#   6,
#   9,
#   338,
#   24,
#   5,
#   1],
#  [1,
#   52,
#   4,
#   1,
#   655,
#   55,
#   338,
#   1,
#   656,
#   6,
#   657,
#   19,
#   91,
#   658,
#   437,
#   659,
#   438,
#   660,
#   194,
#   164,
#   3,
#   57,
#   70,
#   6,
#   9,
#   338,
#   24,
#   5,
#   1,
#   226],
#  [71, 1],
#  [71, 1, 18],
#  [71, 1, 18, 1],
#  [71, 1, 18, 1, 4],
#  [71, 1, 18, 1, 4, 227],
#  [71, 1, 18, 1, 4, 227, 18],
#  [71, 1, 18, 1, 4, 227, 18, 27],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61, 135],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61, 135, 27],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61, 135, 27, 4],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61, 135, 27, 4, 227],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61, 135, 27, 4, 227, 61],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61, 135, 27, 4, 227, 61, 135],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61, 135, 27, 4, 227, 61, 135, 9],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61, 135, 27, 4, 227, 61, 135, 9, 195],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61, 135, 27, 4, 227, 61, 135, 9, 195, 9],
#  [71, 1, 18, 1, 4, 227, 18, 27, 61, 135, 27, 4, 227, 61, 135, 9, 195, 9, 4],
#  [71,
#   1,
#   18,
#   1,
#   4,
#   227,
#   18,
#   27,
#   61,
#   135,
#   27,
#   4,
#   227,
#   61,
#   135,
#   9,
#   195,
#   9,
#   4,
#   227],
#  [71,
#   1,
#   18,
#   1,
#   4,
#   227,
#   18,
#   27,
#   61,
#   135,
#   27,
#   4,
#   227,
#   61,
#   135,
#   9,
#   195,
#   9,
#   4,
#   227,
#   195],
#  [278, 14],
#  [278, 14, 661],
#  [278, 14, 661, 70],
#  [278, 14, 661, 70, 6],
#  [278, 14, 661, 70, 6, 9],
#  [92, 72],
#  [92, 72, 163],
#  [92, 72, 163, 13],
#  [92, 72, 163, 13, 22],
#  [92, 72, 163, 13, 22, 662],
#  [92, 72, 163, 13, 22, 662, 34],
#  [92, 72, 163, 13, 22, 662, 34, 663],
#  [165, 664],
#  [165, 664, 665],
#  [165, 664, 665, 16],
#  [165, 664, 665, 16, 228],
#  [165, 666],
#  [165, 666, 667],
#  [165, 666, 667, 113],
#  [165, 666, 667, 113, 279],
#  [165, 666, 667, 113, 279, 228],
#  [52, 339],
#  [52, 339, 16],
#  [52, 339, 16, 77],
#  [52, 339, 16, 77, 668],
#  [19, 163],
#  [19, 163, 136],
#  [19, 163, 136, 439],
#  [19, 163, 136, 439, 52],
#  [19, 163, 136, 439, 52, 339],
#  [19, 163, 136, 439, 52, 339, 6],
#  [19, 163, 136, 439, 52, 339, 6, 89],
#  [19, 163, 136, 439, 52, 339, 6, 89, 125],
#  [19, 163, 136, 439, 52, 339, 6, 89, 125, 17],
#  [19, 163, 136, 439, 52, 339, 6, 89, 125, 17, 669],
#  [19, 163, 136, 439, 52, 339, 6, 89, 125, 17, 669, 440],
#  [19, 163, 136, 439, 52, 339, 6, 89, 125, 17, 669, 440, 5],
#  [19, 163, 136, 439, 52, 339, 6, 89, 125, 17, 669, 440, 5, 89],
#  [19, 163, 136, 439, 52, 339, 6, 89, 125, 17, 669, 440, 5, 89, 125],
#  [19, 163, 136, 439, 52, 339, 6, 89, 125, 17, 669, 440, 5, 89, 125, 225],
#  [22, 441],
#  [22, 441, 340],
#  [22, 441, 340, 24],
#  [22, 441, 340, 24, 229],
#  [22, 441, 340, 24, 229, 50],
#  [22, 441, 340, 24, 229, 50, 166],
#  [22, 441, 340, 24, 229, 50, 166, 4],
#  [22, 441, 340, 24, 229, 50, 166, 4, 151],
#  [22, 441, 340, 24, 229, 50, 166, 4, 151, 26],
#  [22, 441, 340, 24, 229, 50, 166, 4, 151, 26, 1],
#  [22, 441, 340, 24, 229, 50, 166, 4, 151, 26, 1, 226],
#  [1, 52],
#  [1, 52, 4],
#  [1, 52, 4, 22],
#  [1, 52, 4, 22, 441],
#  [1, 52, 4, 22, 441, 340],
#  [1, 52, 4, 22, 441, 340, 24],
#  [1, 52, 4, 22, 441, 340, 24, 12],
#  [1, 52, 4, 22, 441, 340, 24, 12, 13],
#  [1, 52, 4, 22, 441, 340, 24, 12, 13, 442],
#  [1, 52, 4, 22, 441, 340, 24, 12, 13, 442, 73],
#  [1, 52, 4, 22, 441, 340, 24, 12, 13, 442, 73, 5],
#  [1, 52, 4, 22, 441, 340, 24, 12, 13, 442, 73, 5, 225],
#  [280, 93],
#  [280, 93, 16],
#  [280, 93, 16, 230],
#  [280, 93, 16, 230, 73],
#  [280, 93, 16, 230, 73, 5],
#  [280, 93, 16, 230, 73, 5, 225],
#  [64, 226],
#  [64, 226, 33],
#  [64, 226, 33, 30],
#  [64, 226, 33, 30, 670],
#  [64, 226, 33, 30, 670, 135],
#  [64, 226, 33, 30, 670, 135, 196],
#  [197, 226],
#  [197, 226, 33],
#  [197, 226, 33, 671],
#  [197, 226, 33, 671, 30],
#  [197, 226, 33, 671, 30, 43],
#  [197, 226, 33, 671, 30, 43, 53],
#  [197, 226, 33, 671, 30, 43, 53, 135],
#  [197, 226, 33, 671, 30, 43, 53, 135, 21],
#  [72, 226],
#  [72, 226, 33],
#  [72, 226, 33, 341],
#  [72, 226, 33, 341, 152],
#  [72, 226, 33, 341, 152, 231],
#  [72, 226, 33, 341, 152, 231, 152],
#  [72, 226, 33, 341, 152, 231, 152, 231],
#  [72, 226, 33, 341, 152, 231, 152, 231, 163],
#  [72, 226, 33, 341, 152, 231, 152, 231, 163, 13],
#  [72, 226, 33, 341, 152, 231, 152, 231, 163, 13, 672],
#  [72, 226, 33, 341, 152, 231, 152, 231, 163, 13, 672, 443],
#  [72, 226, 33, 341, 152, 231, 152, 231, 163, 13, 672, 443, 198],
#  [72, 226, 33, 341, 152, 231, 152, 231, 163, 13, 672, 443, 198, 444],
#  [126, 16],
#  [126, 16, 673],
#  [126, 16, 673, 674],
#  [126, 16, 673, 674, 340],
#  [126, 16, 673, 674, 340, 675],
#  [126, 16, 673, 674, 340, 675, 4],
#  [126, 16, 673, 674, 340, 675, 4, 676],
#  [126, 16, 673, 674, 340, 675, 4, 676, 342],
#  [126, 16, 673, 674, 340, 675, 4, 676, 342, 3],
#  [126, 16, 673, 674, 340, 675, 4, 676, 342, 3, 2],
#  [126, 16, 673, 674, 340, 675, 4, 676, 342, 3, 2, 134],
#  [126, 16, 673, 674, 340, 675, 4, 676, 342, 3, 2, 134, 93],
#  [126, 16, 673, 674, 340, 675, 4, 676, 342, 3, 2, 134, 93, 16],
#  [126, 16, 673, 674, 340, 675, 4, 676, 342, 3, 2, 134, 93, 16, 445],
#  [126, 16, 673, 674, 340, 675, 4, 676, 342, 3, 2, 134, 93, 16, 445, 337],
#  [126, 16, 673, 674, 340, 675, 4, 676, 342, 3, 2, 134, 93, 16, 445, 337, 343],
#  [126,
#   16,
#   673,
#   674,
#   340,
#   675,
#   4,
#   676,
#   342,
#   3,
#   2,
#   134,
#   93,
#   16,
#   445,
#   337,
#   343,
#   6],
#  [126,
#   16,
#   673,
#   674,
#   340,
#   675,
#   4,
#   676,
#   342,
#   3,
#   2,
#   134,
#   93,
#   16,
#   445,
#   337,
#   343,
#   6,
#   9],
#  [677, 446],
#  [677, 446, 7],
#  [677, 446, 7, 109],
#  [199, 447],
#  [199, 447, 65],
#  [199, 447, 65, 167],
#  [77, 74],
#  [77, 74, 678],
#  [77, 74, 678, 281],
#  [56, 679],
#  [56, 679, 680],
#  [56, 679, 680, 681],
#  [682, 448],
#  [682, 448, 28],
#  [682, 448, 28, 683],
#  [282, 684],
#  [282, 684, 14],
#  [282, 684, 14, 137],
#  [344, 283],
#  [344, 283, 685],
#  [344, 283, 685, 449],
#  [200, 686],
#  [200, 686, 20],
#  [200, 686, 20, 66],
#  [89, 92],
#  [89, 92, 9],
#  [89, 92, 9, 15],
#  [89, 92, 9, 15, 201],
#  [89, 92, 9, 15, 201, 232],
#  [89, 92, 9, 15, 201, 232, 168],
#  [89, 92, 9, 15, 201, 232, 168, 7],
#  [89, 92, 9, 15, 201, 232, 168, 7, 78],
#  [89, 92, 9, 15, 201, 232, 168, 7, 78, 51],
#  [89, 92, 9, 15, 201, 232, 168, 7, 78, 51, 450],
#  [89, 92, 9, 15, 201, 232, 168, 7, 78, 51, 450, 10],
#  [89, 92, 9, 15, 201, 232, 168, 7, 78, 51, 450, 10, 284],
#  [89, 92, 9, 15, 201, 232, 168, 7, 78, 51, 450, 10, 284, 687],
#  [89, 92, 9, 15, 201, 232, 168, 7, 78, 51, 450, 10, 284, 687, 9],
#  [89, 92, 9, 15, 201, 232, 168, 7, 78, 51, 450, 10, 284, 687, 9, 54],
#  [89, 92, 9, 15, 201, 232, 168, 7, 78, 51, 450, 10, 284, 687, 9, 54, 97],
#  [89, 92, 9, 15, 201, 232, 168, 7, 78, 51, 450, 10, 284, 687, 9, 54, 97, 74],
#  [89,
#   92,
#   9,
#   15,
#   201,
#   232,
#   168,
#   7,
#   78,
#   51,
#   450,
#   10,
#   284,
#   687,
#   9,
#   54,
#   97,
#   74,
#   21],
#  [345, 84],
#  [345, 84, 5],
#  [345, 84, 5, 1],
#  [345, 84, 5, 1, 9],
#  [345, 84, 5, 1, 9, 15],
#  [98, 9],
#  [98, 9, 125],
#  [98, 9, 125, 163],
#  [98, 9, 125, 163, 688],
#  [98, 9, 125, 163, 688, 1],
#  [98, 9, 125, 163, 688, 1, 345],
#  [98, 9, 125, 163, 688, 1, 345, 84],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1, 9],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1, 9, 15],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1, 9, 15, 202],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1, 9, 15, 202, 54],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1, 9, 15, 202, 54, 1],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1, 9, 15, 202, 54, 1, 78],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1, 9, 15, 202, 54, 1, 78, 11],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1, 9, 15, 202, 54, 1, 78, 11, 8],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1, 9, 15, 202, 54, 1, 78, 11, 8, 285],
#  [98, 9, 125, 163, 688, 1, 345, 84, 1, 9, 15, 202, 54, 1, 78, 11, 8, 285, 44],
#  [98,
#   9,
#   125,
#   163,
#   688,
#   1,
#   345,
#   84,
#   1,
#   9,
#   15,
#   202,
#   54,
#   1,
#   78,
#   11,
#   8,
#   285,
#   44,
#   286],
#  [98,
#   9,
#   125,
#   163,
#   688,
#   1,
#   345,
#   84,
#   1,
#   9,
#   15,
#   202,
#   54,
#   1,
#   78,
#   11,
#   8,
#   285,
#   44,
#   286,
#   233],
#  [98,
#   9,
#   125,
#   163,
#   688,
#   1,
#   345,
#   84,
#   1,
#   9,
#   15,
#   202,
#   54,
#   1,
#   78,
#   11,
#   8,
#   285,
#   44,
#   286,
#   233,
#   36],
#  [192, 346],
#  [192, 346, 4],
#  [192, 346, 4, 347],
#  [192, 346, 4, 347, 54],
#  [192, 346, 4, 347, 54, 1],
#  [192, 346, 4, 347, 54, 1, 348],
#  [93, 16],
#  [93, 16, 124],
#  [93, 16, 124, 278],
#  [93, 16, 124, 278, 55],
#  [93, 16, 124, 278, 55, 16],
#  [93, 16, 124, 278, 55, 16, 689],
#  [93, 16, 124, 278, 55, 16, 689, 3],
#  [93, 16, 124, 278, 55, 16, 689, 3, 98],
#  [93, 16, 124, 278, 55, 16, 689, 3, 98, 2],
#  [93, 16, 124, 278, 55, 16, 689, 3, 98, 2, 9],
#  [93, 16, 124, 278, 55, 16, 689, 3, 98, 2, 9, 125],
#  [349, 690],
#  [349, 690, 287],
#  [349, 690, 287, 202],
#  [349, 690, 287, 202, 49],
#  [349, 690, 287, 202, 49, 78],
#  [349, 690, 287, 202, 49, 78, 11],
#  [98, 2],
#  [98, 2, 127],
#  [98, 2, 127, 16],
#  [98, 2, 127, 16, 347],
#  [98, 2, 127, 16, 347, 54],
#  [98, 2, 127, 16, 347, 54, 1],
#  [98, 2, 127, 16, 347, 54, 1, 348],
#  [44, 16],
#  [44, 16, 691],
#  [44, 16],
#  [44, 16, 114],
#  [44, 16, 114, 6],
#  [44, 16, 114, 6, 2],
#  [44, 16, 114, 6, 2, 234],
#  [44, 16, 114, 6, 2, 234, 138],
#  [44, 16, 114, 6, 2, 234, 138, 6],
#  [44, 16, 114, 6, 2, 234, 138, 6, 55],
#  [44, 16, 114, 6, 2, 234, 138, 6, 55, 350],
#  [44, 16, 114, 6, 2, 234, 138, 6, 55, 350, 16],
#  [44, 16, 114, 6, 2, 234, 138, 6, 55, 350, 16, 193],
#  [44, 16, 114, 6, 2, 234, 138, 6, 55, 350, 16, 193, 235],
#  [235, 16],
#  [235, 16, 35],
#  [235, 16, 35, 3],
#  [235, 16, 35, 3, 692],
#  [235, 16, 35, 3, 692, 451],
#  [235, 16, 35, 3, 692, 451, 351],
#  [235, 16, 35, 3, 692, 451, 351, 2],
#  [235, 16, 35, 3, 692, 451, 351, 2, 15],
#  [235, 16, 35, 3, 692, 451, 351, 2, 15, 6],
#  [235, 16, 35, 3, 692, 451, 351, 2, 15, 6, 352],
#  [235, 16, 35, 3, 692, 451, 351, 2, 15, 6, 352, 106],
#  [235, 16, 35, 3, 692, 451, 351, 2, 15, 6, 352, 106, 36],
#  [235, 16, 35, 3, 692, 451, 351, 2, 15, 6, 352, 106, 36, 4],
#  [235, 16, 35, 3, 692, 451, 351, 2, 15, 6, 352, 106, 36, 4, 1],
#  [235, 16, 35, 3, 692, 451, 351, 2, 15, 6, 352, 106, 36, 4, 1, 148],
#  [235, 16, 35, 3, 692, 451, 351, 2, 15, 6, 352, 106, 36, 4, 1, 148, 14],
#  [235, 16, 35, 3, 692, 451, 351, 2, 15, 6, 352, 106, 36, 4, 1, 148, 14, 191],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3,
#   89],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3,
#   89,
#   15],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3,
#   89,
#   15,
#   93],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3,
#   89,
#   15,
#   93,
#   16],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3,
#   89,
#   15,
#   93,
#   16,
#   139],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3,
#   89,
#   15,
#   93,
#   16,
#   139,
#   73],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3,
#   89,
#   15,
#   93,
#   16,
#   139,
#   73,
#   5],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3,
#   89,
#   15,
#   93,
#   16,
#   139,
#   73,
#   5,
#   235],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3,
#   89,
#   15,
#   93,
#   16,
#   139,
#   73,
#   5,
#   235,
#   6],
#  [235,
#   16,
#   35,
#   3,
#   692,
#   451,
#   351,
#   2,
#   15,
#   6,
#   352,
#   106,
#   36,
#   4,
#   1,
#   148,
#   14,
#   191,
#   3,
#   169,
#   288,
#   3,
#   89,
#   15,
#   93,
#   16,
#   139,
#   73,
#   5,
#   235,
#   6,
#   9],
#  [198, 153],
#  [198, 153, 236],
#  [198, 153, 236, 198],
#  [198, 153, 236, 198, 153],
#  [198, 153, 236, 198, 153, 235],
#  [198, 153, 236, 198, 153, 235, 693],
#  [198, 153, 236, 198, 153, 235, 693, 54],
#  [198, 153, 236, 198, 153, 235, 693, 54, 139],
#  [198, 153, 236, 198, 153, 235, 693, 54, 139, 694],
#  [198, 153, 236, 198, 153, 235, 693, 54, 139, 694, 452],
#  [198, 153, 236, 198, 153, 235, 693, 54, 139, 694, 452, 115],
#  [198, 153, 236, 198, 153, 235, 693, 54, 139, 694, 452, 115, 453],
#  [198, 153, 236, 198, 153, 235, 693, 54, 139, 694, 452, 115, 453, 353],
#  [198, 153, 236, 198, 153, 235, 693, 54, 139, 694, 452, 115, 453, 353, 2],
#  [198, 153, 236, 198, 153, 235, 693, 54, 139, 694, 452, 115, 453, 353, 2, 452],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354,
#   59],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354,
#   59,
#   50],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354,
#   59,
#   50,
#   13],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354,
#   59,
#   50,
#   13,
#   114],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354,
#   59,
#   50,
#   13,
#   114,
#   17],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354,
#   59,
#   50,
#   13,
#   114,
#   17,
#   4],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354,
#   59,
#   50,
#   13,
#   114,
#   17,
#   4,
#   1],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354,
#   59,
#   50,
#   13,
#   114,
#   17,
#   4,
#   1,
#   198],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354,
#   59,
#   50,
#   13,
#   114,
#   17,
#   4,
#   1,
#   198,
#   153],
#  [198,
#   153,
#   236,
#   198,
#   153,
#   235,
#   693,
#   54,
#   139,
#   694,
#   452,
#   115,
#   453,
#   353,
#   2,
#   452,
#   695,
#   67,
#   2,
#   234,
#   153,
#   696,
#   13,
#   354,
#   59,
#   50,
#   13,
#   114,
#   17,
#   4,
#   1,
#   198,
#   153,
#   236],
#  [237, 153],
#  [237, 153, 236],
#  [237, 153, 236, 1],
#  [237, 153, 236, 1, 237],
#  [237, 153, 236, 1, 237, 153],
#  [237, 153, 236, 1, 237, 153, 236],
#  [237, 153, 236, 1, 237, 153, 236, 202],
#  [237, 153, 236, 1, 237, 153, 236, 202, 54],
#  [237, 153, 236, 1, 237, 153, 236, 202, 54, 8],
#  [237, 153, 236, 1, 237, 153, 236, 202, 54, 8, 697],
#  [237, 153, 236, 1, 237, 153, 236, 202, 54, 8, 697, 54],
#  [237, 153, 236, 1, 237, 153, 236, 202, 54, 8, 697, 54, 115],
#  [237, 153, 236, 1, 237, 153, 236, 202, 54, 8, 697, 54, 115, 453],
#  [237, 153, 236, 1, 237, 153, 236, 202, 54, 8, 697, 54, 115, 453, 238],
#  [237, 153, 236, 1, 237, 153, 236, 202, 54, 8, 697, 54, 115, 453, 238, 8],
#  [237, 153, 236, 1, 237, 153, 236, 202, 54, 8, 697, 54, 115, 453, 238, 8, 59],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13,
#   354],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13,
#   354,
#   41],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13,
#   354,
#   41,
#   2],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13,
#   354,
#   41,
#   2,
#   134],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13,
#   354,
#   41,
#   2,
#   134,
#   17],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13,
#   354,
#   41,
#   2,
#   134,
#   17,
#   4],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13,
#   354,
#   41,
#   2,
#   134,
#   17,
#   4,
#   1],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13,
#   354,
#   41,
#   2,
#   134,
#   17,
#   4,
#   1,
#   237],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13,
#   354,
#   41,
#   2,
#   134,
#   17,
#   4,
#   1,
#   237,
#   153],
#  [237,
#   153,
#   236,
#   1,
#   237,
#   153,
#   236,
#   202,
#   54,
#   8,
#   697,
#   54,
#   115,
#   453,
#   238,
#   8,
#   59,
#   13,
#   354,
#   41,
#   2,
#   134,
#   17,
#   4,
#   1,
#   237,
#   153,
#   236],
#  [99, 235],
#  [99, 235, 6],
#  [99, 235, 6, 1],
#  [99, 235, 6, 1, 9],
#  [99, 235, 6, 1, 9, 15],
#  [99, 235, 6, 1, 9, 15, 16],
#  [99, 235, 6, 1, 9, 15, 16, 50],
#  [99, 235, 6, 1, 9, 15, 16, 50, 114],
#  [99, 235, 6, 1, 9, 15, 16, 50, 114, 8],
#  [99, 235, 6, 1, 9, 15, 16, 50, 114, 8, 16],
#  [99, 235, 6, 1, 9, 15, 16, 50, 114, 8, 16, 354],
#  [434, 8],
#  [434, 8, 287],
#  [1, 134],
#  [1, 134, 4],
#  [1, 134, 4, 1],
#  [1, 134, 4, 1, 190],
#  [1, 134, 4, 1, 190, 15],
#  [1, 134, 4, 1, 190, 15, 55],
#  [1, 134, 4, 1, 190, 15, 55, 454],
#  [1, 134, 4, 1, 190, 15, 55, 454, 1],
#  [1, 134, 4, 1, 190, 15, 55, 454, 1, 9],
#  [1, 134, 4, 1, 190, 15, 55, 454, 1, 9, 15],
#  [1, 134, 4, 1, 190, 15, 55, 454, 1, 9, 15, 150],
#  [1, 134, 4, 1, 190, 15, 55, 454, 1, 9, 15, 150, 336],
#  [1, 134, 4, 1, 190, 15, 55, 454, 1, 9, 15, 150, 336, 106],
#  [1, 134, 4, 1, 190, 15, 55, 454, 1, 9, 15, 150, 336, 106, 154],
#  [1, 134, 4, 1, 190, 15, 55, 454, 1, 9, 15, 150, 336, 106, 154, 57],
#  [1, 134, 4, 1, 190, 15, 55, 454, 1, 9, 15, 150, 336, 106, 154, 57, 36],
#  [1, 134, 4, 1, 190, 15, 55, 454, 1, 9, 15, 150, 336, 106, 154, 57, 36, 12],
#  [1,
#   134,
#   4,
#   1,
#   190,
#   15,
#   55,
#   454,
#   1,
#   9,
#   15,
#   150,
#   336,
#   106,
#   154,
#   57,
#   36,
#   12,
#   13],
#  [1,
#   134,
#   4,
#   1,
#   190,
#   15,
#   55,
#   454,
#   1,
#   9,
#   15,
#   150,
#   336,
#   106,
#   154,
#   57,
#   36,
#   12,
#   13,
#   455],
#  [1,
#   134,
#   4,
#   1,
#   190,
#   15,
#   55,
#   454,
#   1,
#   9,
#   15,
#   150,
#   336,
#   106,
#   154,
#   57,
#   36,
#   12,
#   13,
#   455,
#   698],
#  [1,
#   134,
#   4,
#   1,
#   190,
#   15,
#   55,
#   454,
#   1,
#   9,
#   15,
#   150,
#   336,
#   106,
#   154,
#   57,
#   36,
#   12,
#   13,
#   455,
#   698,
#   41],
#  [1,
#   134,
#   4,
#   1,
#   190,
#   15,
#   55,
#   454,
#   1,
#   9,
#   15,
#   150,
#   336,
#   106,
#   154,
#   57,
#   36,
#   12,
#   13,
#   455,
#   698,
#   41,
#   2],
#  [1,
#   134,
#   4,
#   1,
#   190,
#   15,
#   55,
#   454,
#   1,
#   9,
#   15,
#   150,
#   336,
#   106,
#   154,
#   57,
#   36,
#   12,
#   13,
#   455,
#   698,
#   41,
#   2,
#   190],
#  [1, 9],
#  [1, 9, 15],
#  [1, 9, 15, 4],
#  [1, 9, 15, 4, 193],
#  [1, 9, 15, 4, 193, 6],
#  [1, 9, 15, 4, 193, 6, 352],
#  [1, 9, 15, 4, 193, 6, 352, 355],
#  [17, 352],
#  [17, 352, 355],
#  [17, 352, 355, 4],
#  [17, 352, 355, 4, 699],
#  [17, 352, 355, 4, 699, 5],
#  [17, 352, 355, 4, 699, 5, 44],
#  [17, 352, 355, 4, 699, 5, 44, 6],
#  [17, 352, 355, 4, 699, 5, 44, 6, 1],
#  [17, 352, 355, 4, 699, 5, 44, 6, 1, 289],
#  [17, 352, 355, 4, 699, 5, 44, 6, 1, 289, 356],
#  [17, 352, 355, 4, 699, 5, 44, 6, 1, 289, 356, 2],
#  [17, 352, 355, 4, 699, 5, 44, 6, 1, 289, 356, 2, 134],
#  [17, 352, 355, 4, 699, 5, 44, 6, 1, 289, 356, 2, 134, 456],
#  [17, 352, 355, 4, 699, 5, 44, 6, 1, 289, 356, 2, 134, 456, 124],
#  [17, 352, 355, 4, 699, 5, 44, 6, 1, 289, 356, 2, 134, 456, 124, 345],
#  [17, 352, 355, 4, 699, 5, 44, 6, 1, 289, 356, 2, 134, 456, 124, 345, 357],
#  [17, 352, 355, 4, 699, 5, 44, 6, 1, 289, 356, 2, 134, 456, 124, 345, 357, 8],
#  [17,
#   352,
#   355,
#   4,
#   699,
#   5,
#   44,
#   6,
#   1,
#   289,
#   356,
#   2,
#   134,
#   456,
#   124,
#   345,
#   357,
#   8,
#   700],
#  [17,
#   352,
#   355,
#   4,
#   699,
#   5,
#   44,
#   6,
#   1,
#   289,
#   356,
#   2,
#   134,
#   456,
#   124,
#   345,
#   357,
#   8,
#   700,
#   454],
#  [17,
#   352,
#   355,
#   4,
#   699,
#   5,
#   44,
#   6,
#   1,
#   289,
#   356,
#   2,
#   134,
#   456,
#   124,
#   345,
#   357,
#   8,
#   700,
#   454,
#   2],
#  [17,
#   352,
#   355,
#   4,
#   699,
#   5,
#   44,
#   6,
#   1,
#   289,
#   356,
#   2,
#   134,
#   456,
#   124,
#   345,
#   357,
#   8,
#   700,
#   454,
#   2,
#   15],
#  [17,
#   352,
#   355,
#   4,
#   699,
#   5,
#   44,
#   6,
#   1,
#   289,
#   356,
#   2,
#   134,
#   456,
#   124,
#   345,
#   357,
#   8,
#   700,
#   454,
#   2,
#   15,
#   150],
#  [17,
#   352,
#   355,
#   4,
#   699,
#   5,
#   44,
#   6,
#   1,
#   289,
#   356,
#   2,
#   134,
#   456,
#   124,
#   345,
#   357,
#   8,
#   700,
#   454,
#   2,
#   15,
#   150,
#   22],
#  [17,
#   352,
#   355,
#   4,
#   699,
#   5,
#   44,
#   6,
#   1,
#   289,
#   356,
#   2,
#   134,
#   456,
#   124,
#   345,
#   357,
#   8,
#   700,
#   454,
#   2,
#   15,
#   150,
#   22,
#   701],
#  [170, 79],
#  [9, 106],
#  [9, 106, 358],
#  [9, 106, 358, 1],
#  [9, 106, 358, 1, 702],
#  [9, 106, 358, 1, 702, 5],
#  [9, 106, 358, 1, 702, 5, 703],
#  [9, 106, 358, 1, 702, 5, 703, 170],
#  [9, 106, 358, 1, 702, 5, 703, 170, 79],
#  [9, 106, 358, 1, 702, 5, 703, 170, 79, 55],
#  [9, 106, 358, 1, 702, 5, 703, 170, 79, 55, 4],
#  [9, 106, 358, 1, 702, 5, 703, 170, 79, 55, 4, 35],
#  [9, 106, 358, 1, 702, 5, 703, 170, 79, 55, 4, 35, 3],
#  [9, 106, 358, 1, 702, 5, 703, 170, 79, 55, 4, 35, 3, 704],
#  [9, 106, 358, 1, 702, 5, 703, 170, 79, 55, 4, 35, 3, 704, 705],
#  [9, 106, 358, 1, 702, 5, 703, 170, 79, 55, 4, 35, 3, 704, 705, 457],
#  [9, 106, 358, 1, 702, 5, 703, 170, 79, 55, 4, 35, 3, 704, 705, 457, 706],
#  [9, 106, 358, 1, 702, 5, 703, 170, 79, 55, 4, 35, 3, 704, 705, 457, 706, 14],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7,
#   10],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7,
#   10,
#   100],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7,
#   10,
#   100,
#   51],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7,
#   10,
#   100,
#   51,
#   17],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7,
#   10,
#   100,
#   51,
#   17,
#   4],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7,
#   10,
#   100,
#   51,
#   17,
#   4,
#   46],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7,
#   10,
#   100,
#   51,
#   17,
#   4,
#   46,
#   40],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7,
#   10,
#   100,
#   51,
#   17,
#   4,
#   46,
#   40,
#   10],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7,
#   10,
#   100,
#   51,
#   17,
#   4,
#   46,
#   40,
#   10,
#   46],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
#   168,
#   7,
#   78,
#   7,
#   10,
#   100,
#   51,
#   17,
#   4,
#   46,
#   40,
#   10,
#   46,
#   14],
#  [9,
#   106,
#   358,
#   1,
#   702,
#   5,
#   703,
#   170,
#   79,
#   55,
#   4,
#   35,
#   3,
#   704,
#   705,
#   457,
#   706,
#   14,
#   707,
#   51,
#   11,
#   4,
#   35,
#   3,
#   94,
#   95,
#   67,
#   2,
#   458,
#   201,
#   232,
# ...
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9,
#   46],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9,
#   46,
#   141],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9,
#   46,
#   141,
#   1],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9,
#   46,
#   141,
#   1,
#   27],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9,
#   46,
#   141,
#   1,
#   27,
#   9],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9,
#   46,
#   141,
#   1,
#   27,
#   9,
#   46],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9,
#   46,
#   141,
#   1,
#   27,
#   9,
#   46,
#   98],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9,
#   46,
#   141,
#   1,
#   27,
#   9,
#   46,
#   98,
#   362],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9,
#   46,
#   141,
#   1,
#   27,
#   9,
#   46,
#   98,
#   362,
#   3],
#  [124,
#   113,
#   466,
#   5,
#   17,
#   172,
#   243,
#   45,
#   17,
#   7,
#   1,
#   129,
#   22,
#   64,
#   52,
#   195,
#   28,
#   27,
#   129,
#   1,
#   28,
#   52,
#   715,
#   7,
#   10,
#   100,
#   129,
#   8,
#   244,
#   467,
#   54,
#   100,
#   7,
#   85,
#   10,
#   129,
#   716,
#   8,
#   244,
#   54,
#   467,
#   7,
#   1,
#   43,
#   27,
#   18,
#   9,
#   61,
#   46,
#   53,
#   129,
#   8,
#   244,
#   204,
#   70,
#   7,
#   717,
#   1,
#   85,
#   10,
#   245,
#   58,
#   718,
#   110,
#   70,
#   360,
#   195,
#   4,
#   35,
#   361,
#   172,
#   28,
#   27,
#   1,
#   18,
#   28,
#   1,
#   30,
#   30,
#   245,
#   719,
#   2,
#   234,
#   24,
#   3,
#   204,
#   70,
#   7,
#   1,
#   27,
#   9,
#   46,
#   1,
#   27,
#   9,
#   46,
#   141,
#   1,
#   27,
#   9,
#   46,
#   98,
#   362,
#   3,
#   141],
#  [203, 44],
#  [203, 44],
#  [203, 44, 363],
#  [203, 44, 363, 468],
#  [203, 44, 363, 468, 291],
#  [205, 16],
#  [205, 16, 124],
#  [205, 16, 124, 5],
#  [205, 16, 124, 5, 2],
#  [205, 16, 124, 5, 2, 292],
#  [205, 16, 124, 5, 2, 292, 35],
#  [205, 16, 124, 5, 2, 292, 35, 68],
#  [205, 16, 124, 5, 2, 292, 35, 68, 6],
#  [205, 16, 124, 5, 2, 292, 35, 68, 6, 9],
#  [205, 16, 124, 5, 2, 292, 35, 68, 6, 9, 106],
#  [294, 12],
#  [294, 12, 13],
#  [294, 12, 13, 7],
#  [294, 12, 13, 7, 28],
#  [294, 12, 13, 7, 28, 194],
#  [294, 12, 13, 7, 28, 194, 16],
#  [294, 12, 13, 7, 28, 194, 16, 203],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68, 7],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68, 7, 27],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68, 7, 27, 43],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68, 7, 27, 43, 9],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68, 7, 27, 43, 9, 18],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68, 7, 27, 43, 9, 18, 7],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68, 7, 27, 43, 9, 18, 7, 130],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68, 7, 27, 43, 9, 18, 7, 130, 130],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68, 7, 27, 43, 9, 18, 7, 130, 130, 27],
#  [294, 12, 13, 7, 28, 194, 16, 203, 68, 7, 27, 43, 9, 18, 7, 130, 130, 27, 9],
#  [294,
#   12,
#   13,
#   7,
#   28,
#   194,
#   16,
#   203,
#   68,
#   7,
#   27,
#   43,
#   9,
#   18,
#   7,
#   130,
#   130,
#   27,
#   9,
#   721],
#  [294,
#   12,
#   13,
#   7,
#   28,
#   194,
#   16,
#   203,
#   68,
#   7,
#   27,
#   43,
#   9,
#   18,
#   7,
#   130,
#   130,
#   27,
#   9,
#   721,
#   7],
#  [294,
#   12,
#   13,
#   7,
#   28,
#   194,
#   16,
#   203,
#   68,
#   7,
#   27,
#   43,
#   9,
#   18,
#   7,
#   130,
#   130,
#   27,
#   9,
#   721,
#   7,
#   130],
#  [294,
#   12,
#   13,
#   7,
#   28,
#   194,
#   16,
#   203,
#   68,
#   7,
#   27,
#   43,
#   9,
#   18,
#   7,
#   130,
#   130,
#   27,
#   9,
#   721,
#   7,
#   130,
#   27],
#  [294,
#   12,
#   13,
#   7,
#   28,
#   194,
#   16,
#   203,
#   68,
#   7,
#   27,
#   43,
#   9,
#   18,
#   7,
#   130,
#   130,
#   27,
#   9,
#   721,
#   7,
#   130,
#   27,
#   9],
#  [294,
#   12,
#   13,
#   7,
#   28,
#   194,
#   16,
#   203,
#   68,
#   7,
#   27,
#   43,
#   9,
#   18,
#   7,
#   130,
#   130,
#   27,
#   9,
#   721,
#   7,
#   130,
#   27,
#   9,
#   130],
#  [294,
#   12,
#   13,
#   7,
#   28,
#   194,
#   16,
#   203,
#   68,
#   7,
#   27,
#   43,
#   9,
#   18,
#   7,
#   130,
#   130,
#   27,
#   9,
#   721,
#   7,
#   130,
#   27,
#   9,
#   130,
#   722],
#  [294,
#   12,
#   13,
#   7,
#   28,
#   194,
#   16,
#   203,
#   68,
#   7,
#   27,
#   43,
#   9,
#   18,
#   7,
#   130,
#   130,
#   27,
#   9,
#   721,
#   7,
#   130,
#   27,
#   9,
#   130,
#   722,
#   50],
#  [294,
#   12,
#   13,
#   7,
#   28,
#   194,
#   16,
#   203,
#   68,
#   7,
#   27,
#   43,
#   9,
#   18,
#   7,
#   130,
#   130,
#   27,
#   9,
#   721,
#   7,
#   130,
#   27,
#   9,
#   130,
#   722,
#   50,
#   228],
#  [4, 2],
#  [4, 2, 723],
#  [4, 2, 723, 470],
#  [4, 2, 723, 470, 62],
#  [33, 173],
#  [33, 173, 2],
#  [33, 173, 2, 724],
#  [33, 246],
#  [33, 246, 13],
#  [33, 246, 13, 725],
#  ...]

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0, 190, 146],
#        [  0,   0,   0, ..., 190, 146,   4],
#        [  0,   0,   0, ..., 146,   4,   1],
#        ...,
#        [  0,   0,   0, ..., 272,  37,  18],
#        [  0,   0,   0, ...,  37,  18, 283],
#        [  0,   0,   0, ...,  18, 283,   7]])

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
print(X.shape,y.shape)
# Out:
# (6261, 104) (6261,)

# %%
from tensorflow.keras.utils import to_categorical
num_classes = np.max(y) + 1  # Automatically set the correct number of classes
y = to_categorical(y, num_classes=num_classes)

# %%
y.shape
# Out:
# (6261, 1164)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense,Bidirectional

# %%
model = Sequential()
model.add(Embedding(num_classes, 150, input_shape=(max_len - 1,)))
model.add(Bidirectional(LSTM(150)))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 104, 150)       │       174,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 300)            │       361,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1164)           │       350,364 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 886,164 (3.38 MB)
#  Trainable params: 886,164 (3.38 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X,y,epochs=100,validation_data=(X,y))
# Out:
# Epoch 1/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 20s 85ms/step - accuracy: 0.0314 - loss: 6.3400 - val_accuracy: 0.0489 - val_loss: 5.7999
# Epoch 2/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 16s 82ms/step - accuracy: 0.0514 - loss: 5.7899 - val_accuracy: 0.0811 - val_loss: 5.4696
# Epoch 3/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 16s 82ms/step - accuracy: 0.0851 - loss: 5.4228 - val_accuracy: 0.1286 - val_loss: 4.9529
# Epoch 4/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 16s 82ms/step - accuracy: 0.1379 - loss: 4.9194 - val_accuracy: 0.1789 - val_loss: 4.4395
# Epoch 5/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 16s 82ms/step - accuracy: 0.1909 - loss: 4.4072 - val_accuracy: 0.2335 - val_loss: 3.9744
# Epoch 6/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 16s 82ms/step - accuracy: 0.2303 - loss: 3.9899 - val_accuracy: 0.2702 - val_loss: 3.5808
# Epoch 7/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 95ms/step - accuracy: 0.2666 - loss: 3.6019 - val_accuracy: 0.3083 - val_loss: 3.2413
# Epoch 8/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - accuracy: 0.2984 - loss: 3.2954 - val_accuracy: 0.3737 - val_loss: 2.9100
# Epoch 9/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.3572 - loss: 2.9779 - val_accuracy: 0.4325 - val_loss: 2.6223
# Epoch 10/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 16s 82ms/step - accuracy: 0.4042 - loss: 2.7067 - val_accuracy: 0.4990 - val_loss: 2.3454
# Epoch 11/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.4625 - loss: 2.4292 - val_accuracy: 0.5461 - val_loss: 2.0996
# Epoch 12/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.5216 - loss: 2.1898 - val_accuracy: 0.6015 - val_loss: 1.8919
# Epoch 13/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.5733 - loss: 1.9564 - val_accuracy: 0.6561 - val_loss: 1.6912
# Epoch 14/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.6206 - loss: 1.7612 - val_accuracy: 0.6882 - val_loss: 1.5154
# Epoch 15/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.6624 - loss: 1.5889 - val_accuracy: 0.7312 - val_loss: 1.3567
# Epoch 16/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.7108 - loss: 1.4085 - val_accuracy: 0.7671 - val_loss: 1.2104
# Epoch 17/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.7493 - loss: 1.2632 - val_accuracy: 0.8019 - val_loss: 1.0925
# Epoch 18/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.7734 - loss: 1.1533 - val_accuracy: 0.8248 - val_loss: 0.9717
# Epoch 19/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.7967 - loss: 1.0531 - val_accuracy: 0.8492 - val_loss: 0.8723
# Epoch 20/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.8273 - loss: 0.9188 - val_accuracy: 0.8674 - val_loss: 0.7819
# Epoch 21/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.8553 - loss: 0.8256 - val_accuracy: 0.8845 - val_loss: 0.7004
# Epoch 22/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.8683 - loss: 0.7584 - val_accuracy: 0.8970 - val_loss: 0.6308
# Epoch 23/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.8845 - loss: 0.6699 - val_accuracy: 0.9094 - val_loss: 0.5699
# Epoch 24/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.8979 - loss: 0.6104 - val_accuracy: 0.9216 - val_loss: 0.5083
# Epoch 25/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.9088 - loss: 0.5445 - val_accuracy: 0.9253 - val_loss: 0.4640
# Epoch 26/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.9215 - loss: 0.4903 - val_accuracy: 0.9336 - val_loss: 0.4207
# Epoch 27/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9284 - loss: 0.4531 - val_accuracy: 0.9404 - val_loss: 0.3797
# Epoch 28/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.9370 - loss: 0.4081 - val_accuracy: 0.9431 - val_loss: 0.3451
# Epoch 29/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.9385 - loss: 0.3663 - val_accuracy: 0.9443 - val_loss: 0.3186
# Epoch 30/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 99ms/step - accuracy: 0.9421 - loss: 0.3411 - val_accuracy: 0.9467 - val_loss: 0.2914
# Epoch 31/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.9371 - loss: 0.3171 - val_accuracy: 0.9476 - val_loss: 0.2712
# Epoch 32/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 810s 4s/step - accuracy: 0.9394 - loss: 0.2929 - val_accuracy: 0.9487 - val_loss: 0.2529
# Epoch 33/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - accuracy: 0.9391 - loss: 0.2899 - val_accuracy: 0.9495 - val_loss: 0.2395
# Epoch 34/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 91ms/step - accuracy: 0.9426 - loss: 0.2535 - val_accuracy: 0.9498 - val_loss: 0.2241
# Epoch 35/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - accuracy: 0.9421 - loss: 0.2406 - val_accuracy: 0.9508 - val_loss: 0.2124
# Epoch 36/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 89ms/step - accuracy: 0.9396 - loss: 0.2418 - val_accuracy: 0.9510 - val_loss: 0.2008
# Epoch 37/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.9478 - loss: 0.2153 - val_accuracy: 0.9513 - val_loss: 0.1933
# Epoch 38/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.9424 - loss: 0.2152 - val_accuracy: 0.9511 - val_loss: 0.1838
# Epoch 39/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.9436 - loss: 0.2033 - val_accuracy: 0.9495 - val_loss: 0.1809
# Epoch 40/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.9461 - loss: 0.1897 - val_accuracy: 0.9510 - val_loss: 0.1749
# Epoch 41/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.9456 - loss: 0.1889 - val_accuracy: 0.9506 - val_loss: 0.1673
# Epoch 42/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.9414 - loss: 0.1870 - val_accuracy: 0.9511 - val_loss: 0.1633
# Epoch 43/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.9460 - loss: 0.1766 - val_accuracy: 0.9510 - val_loss: 0.1570
# Epoch 44/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.9486 - loss: 0.1662 - val_accuracy: 0.9503 - val_loss: 0.1563
# Epoch 45/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.9403 - loss: 0.1768 - val_accuracy: 0.9518 - val_loss: 0.1495
# Epoch 46/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.9448 - loss: 0.1648 - val_accuracy: 0.9511 - val_loss: 0.1512
# Epoch 47/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.9391 - loss: 0.1734 - val_accuracy: 0.9521 - val_loss: 0.1445
# Epoch 48/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.9472 - loss: 0.1587 - val_accuracy: 0.9506 - val_loss: 0.1427
# Epoch 49/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.9421 - loss: 0.1584 - val_accuracy: 0.9510 - val_loss: 0.1420
# Epoch 50/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.9456 - loss: 0.1523 - val_accuracy: 0.9514 - val_loss: 0.1411
# Epoch 51/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.9423 - loss: 0.1656 - val_accuracy: 0.9506 - val_loss: 0.1429
# Epoch 52/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - accuracy: 0.9438 - loss: 0.1614 - val_accuracy: 0.9498 - val_loss: 0.1441
# Epoch 53/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - accuracy: 0.9407 - loss: 0.1638 - val_accuracy: 0.9498 - val_loss: 0.1392
# Epoch 54/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - accuracy: 0.9446 - loss: 0.1511 - val_accuracy: 0.9505 - val_loss: 0.1362
# Epoch 55/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - accuracy: 0.9450 - loss: 0.1481 - val_accuracy: 0.9511 - val_loss: 0.1342
# Epoch 56/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.9423 - loss: 0.1582 - val_accuracy: 0.9510 - val_loss: 0.1318
# Epoch 57/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 95ms/step - accuracy: 0.9463 - loss: 0.1432 - val_accuracy: 0.9513 - val_loss: 0.1299
# Epoch 58/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.9456 - loss: 0.1370 - val_accuracy: 0.9511 - val_loss: 0.1264
# Epoch 59/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.9489 - loss: 0.1365 - val_accuracy: 0.9514 - val_loss: 0.1260
# Epoch 60/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.9480 - loss: 0.1379 - val_accuracy: 0.9511 - val_loss: 0.1255
# Epoch 61/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.9425 - loss: 0.1460 - val_accuracy: 0.9508 - val_loss: 0.1244
# Epoch 62/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.9426 - loss: 0.1427 - val_accuracy: 0.9506 - val_loss: 0.1252
# Epoch 63/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9364 - loss: 0.1511 - val_accuracy: 0.9519 - val_loss: 0.1239
# Epoch 64/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9447 - loss: 0.1403 - val_accuracy: 0.9510 - val_loss: 0.1234
# Epoch 65/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.9468 - loss: 0.1336 - val_accuracy: 0.9508 - val_loss: 0.1220
# Epoch 66/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9405 - loss: 0.1460 - val_accuracy: 0.9390 - val_loss: 0.1784
# Epoch 67/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9213 - loss: 0.2378 - val_accuracy: 0.9457 - val_loss: 0.1703
# Epoch 68/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9383 - loss: 0.1774 - val_accuracy: 0.9513 - val_loss: 0.1283
# Epoch 69/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9393 - loss: 0.1545 - val_accuracy: 0.9513 - val_loss: 0.1263
# Epoch 70/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.9445 - loss: 0.1395 - val_accuracy: 0.9514 - val_loss: 0.1209
# Epoch 71/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.9451 - loss: 0.1347 - val_accuracy: 0.9514 - val_loss: 0.1192
# Epoch 72/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.9451 - loss: 0.1360 - val_accuracy: 0.9513 - val_loss: 0.1183
# Epoch 73/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 91ms/step - accuracy: 0.9433 - loss: 0.1342 - val_accuracy: 0.9513 - val_loss: 0.1182
# Epoch 74/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.9517 - loss: 0.1233 - val_accuracy: 0.9521 - val_loss: 0.1182
# Epoch 75/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.9431 - loss: 0.1300 - val_accuracy: 0.9522 - val_loss: 0.1180
# Epoch 76/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 91ms/step - accuracy: 0.9423 - loss: 0.1370 - val_accuracy: 0.9516 - val_loss: 0.1176
# Epoch 77/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 91ms/step - accuracy: 0.9449 - loss: 0.1338 - val_accuracy: 0.9519 - val_loss: 0.1181
# Epoch 78/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.9420 - loss: 0.1344 - val_accuracy: 0.9518 - val_loss: 0.1165
# Epoch 79/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.9442 - loss: 0.1303 - val_accuracy: 0.9511 - val_loss: 0.1155
# Epoch 80/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9436 - loss: 0.1266 - val_accuracy: 0.9511 - val_loss: 0.1165
# Epoch 81/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9489 - loss: 0.1177 - val_accuracy: 0.9514 - val_loss: 0.1172
# Epoch 82/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.9396 - loss: 0.1401 - val_accuracy: 0.9519 - val_loss: 0.1156
# Epoch 83/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9426 - loss: 0.1310 - val_accuracy: 0.9514 - val_loss: 0.1154
# Epoch 84/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9477 - loss: 0.1247 - val_accuracy: 0.9514 - val_loss: 0.1151
# Epoch 85/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.9423 - loss: 0.1292 - val_accuracy: 0.9510 - val_loss: 0.1158
# Epoch 86/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9480 - loss: 0.1188 - val_accuracy: 0.9519 - val_loss: 0.1144
# Epoch 87/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9437 - loss: 0.1243 - val_accuracy: 0.9521 - val_loss: 0.1138
# Epoch 88/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9499 - loss: 0.1180 - val_accuracy: 0.9513 - val_loss: 0.1145
# Epoch 89/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9435 - loss: 0.1314 - val_accuracy: 0.9516 - val_loss: 0.1143
# Epoch 90/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9456 - loss: 0.1255 - val_accuracy: 0.9518 - val_loss: 0.1137
# Epoch 91/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9403 - loss: 0.1376 - val_accuracy: 0.9519 - val_loss: 0.1137
# Epoch 92/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9421 - loss: 0.1293 - val_accuracy: 0.9514 - val_loss: 0.1144
# Epoch 93/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9451 - loss: 0.1267 - val_accuracy: 0.9513 - val_loss: 0.1132
# Epoch 94/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9452 - loss: 0.1285 - val_accuracy: 0.9518 - val_loss: 0.1124
# Epoch 95/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9434 - loss: 0.1284 - val_accuracy: 0.9518 - val_loss: 0.1121
# Epoch 96/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9429 - loss: 0.1321 - val_accuracy: 0.9506 - val_loss: 0.1127
# Epoch 97/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9455 - loss: 0.1270 - val_accuracy: 0.9518 - val_loss: 0.1119
# Epoch 98/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.9467 - loss: 0.1225 - val_accuracy: 0.9516 - val_loss: 0.1120
# Epoch 99/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9422 - loss: 0.1278 - val_accuracy: 0.9508 - val_loss: 0.1120
# Epoch 100/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9456 - loss: 0.1196 - val_accuracy: 0.9519 - val_loss: 0.1115

# %%
import time
text = "C++ programming"

for i in range(20):
    # Tokenize
    token_text = tokenizer.texts_to_sequences([text])[0]
    # Padding
    padded_token_text = pad_sequences([token_text],maxlen=105,padding='pre')
    # Predict
    pos = np.argmax(model.predict(padded_token_text)).item()
    
    for word,index in tokenizer.word_index.items():
        if index == pos:
            text = text + " "+word
            print(text)
            time.sleep(1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# C++ programming is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# C++ programming is a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# C++ programming is a medium
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# C++ programming is a medium for
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# C++ programming is a medium for us
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# C++ programming is a medium for us to
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# C++ programming is a medium for us to communicate
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# C++ programming is a medium for us to communicate with
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# C++ programming is a medium for us to communicate with computers
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# C++ programming is a medium for us to communicate with computers just
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# C++ programming is a medium for us to communicate with computers just like
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# C++ programming is a medium for us to communicate with computers just like we
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# C++ programming is a medium for us to communicate with computers just like we use
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# C++ programming is a medium for us to communicate with computers just like we use ‘hindi’
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# C++ programming is a medium for us to communicate with computers just like we use ‘hindi’ or
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# C++ programming is a medium for us to communicate with computers just like we use ‘hindi’ or ‘english’
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# C++ programming is a medium for us to communicate with computers just like we use ‘hindi’ or ‘english’ to
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# C++ programming is a medium for us to communicate with computers just like we use ‘hindi’ or ‘english’ to communicate
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# C++ programming is a medium for us to communicate with computers just like we use ‘hindi’ or ‘english’ to communicate with
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# C++ programming is a medium for us to communicate with computers just like we use ‘hindi’ or ‘english’ to communicate with each
